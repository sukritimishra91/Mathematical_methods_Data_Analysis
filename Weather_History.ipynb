# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
weather_history_data=pd.read_csv('weatherHistory.csv')
pd.set_option('precision', 4)
pd.set_option('max_columns', 9)
pd.set_option('display.width', None)

# %%
weather_history_data.tail(5)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  ...  Visibility (km)  Loud Cover  \
# 96448          26.0167  ...          16.1000           0
# 96449          24.5833  ...          15.5526           0
# 96450          22.0389  ...          16.1000           0
# 96451          21.5222  ...          16.1000           0
# 96452          20.4389  ...          15.5204           0
#
#        Pressure (millibars)                           Daily Summary
# 96448               1014.36  Partly cloudy starting in the morning.
# 96449               1015.16  Partly cloudy starting in the morning.
# ...

# %%
weather_history_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)    Humidity  \
# count       96453.0000                96453.0000  96453.0000
# mean           11.9327                   10.8550      0.7349
# std             9.5515                   10.6968      0.1955
# min           -21.8222                  -27.7167      0.0000
# 25%             4.6889                    2.3111      0.6000
# 50%            12.0000                   12.0000      0.7800
# 75%            18.8389                   18.8389      0.8900
# max            39.9056                   39.3444      1.0000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count         96453.0000              96453.0000       96453.0000     96453.0
# mean             10.8106                187.5092          10.3473         0.0
# std               6.9136                107.3834           4.1921         0.0
# min               0.0000                  0.0000           0.0000         0.0
# ...

# %%
print(f'  Data shape = {weather_history_data.shape}')
# Out:
#   Data shape = (96453, 12)

# %%
sample_df = weather_history_data.sample(frac=0.1, random_state=17)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(font_scale=2)
sns.set_style('whitegrid')

# %%
for feature in weather_history_data.columns :
     plt.figure(figsize=(16, 9))
     sns.scatterplot(data=sample_df, x=feature, y='Temperature (C)', 
                     hue='Temperature (C)', 
                     palette='cool', legend=False)

# %%
sns.scatterplot(data=sample_df, x='Apparent Temperature (C)', y='Humidity', 
                     hue='Humidity', 
                     palette='cool', legend=False)

# %%
sns.scatterplot(data=sample_df, x='Temperature (C)', y='Humidity', 
                     hue='Humidity', 
                     palette='cool', legend=False)

# %%
sns.scatterplot(data=sample_df, x='Apparent Temperature (C)', y='Humidity', 
                     hue='Humidity', 
                     palette='cool', legend=False)

# %%
from sklearn.model_selection import train_test_split
df = pd.DataFrame()
df['Temperature (C)'] = weather_history_data['Temperature (C)']
df['Wind Speed (km/h)'] =  weather_history_data['Wind Speed (km/h)']
#df['Apparent Temperature (C)'] = weather_history_data['Apparent Temperature (C)']
df['Humidity'] = weather_history_data['Humidity']
df['Wind Speed (km/h)'] = weather_history_data['Wind Speed (km/h)']
df['Wind Bearing (degrees)'] = weather_history_data['Wind Bearing (degrees)']
df['Visibility (km)	'] = weather_history_data['Visibility (km)']
X_train, X_test, y_train, y_test = \
    train_test_split(df, df['Temperature (C)'], random_state=11)

print(f'Shape of training set = {X_train.shape}')
print(f'Shape of testing  set = {X_test.shape}')

# %%
from sklearn.linear_model import LinearRegression
linear_regression = LinearRegression()
linear_regression.fit(X=X_train, y=y_train)

for i, name in enumerate(df.columns):
    print(f'{name:>11}: {linear_regression.coef_[0]:24.20f}')

print()
print(f'y-intercept: {linear_regression.intercept_:23.20f}')

# %%
import math
from sklearn import metrics

predicted = linear_regression.predict(X_test)
expected  = y_test

r2 = metrics.r2_score(expected, predicted)
r  = math.sqrt(r2)

print(f'coefficient of determination = {r2:.1f}')
print(f'     correlation coefficient = {r:.1f}')

# %%
df1 = pd.DataFrame()

df1['Expected']  = pd.Series(expected)
df1['Predicted'] = pd.Series(predicted)

figure = plt.figure(figsize=(15, 10))

axes = sns.scatterplot(data=df1, x='Expected', y='Predicted', 
                       hue='Predicted', palette='cool', 
                       legend=False)

start = min(expected.min(), predicted.min())
end   = max(expected.max(), predicted.max())

axes.set_xlim(start, end)
axes.set_ylim(start, end)

line = plt.plot([start, end], [start, end], 'k--')

# %%
X_train, X_test, y_train, y_test = train_test_split(weather_history_data[['Apparent Temperature (C)','Humidity','Wind Speed (km/h)','Wind Bearing (degrees)','Visibility (km)','Loud Cover', 'Pressure (millibars)']].values,['Temperature (C)'].values,test_size=0.2)

# %%
from sklearn.model_selection import train_test_split
print(f'Shape of training data: {X_train.shape, y_train.shape}')
print(f'Shape of testing data: {X_test.shape, y_test.shape}')
