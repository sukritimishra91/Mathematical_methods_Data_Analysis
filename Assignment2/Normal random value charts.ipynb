# %% [markdown]
# # Seaborn Charts of Normally Distributed Random Values

# %%
import numpy as np

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(20,8)})

# %%
import random

# %% [markdown]
# ## Generating 1000 normally distributed random values over the range 0-25

# %%
normal_values=[int(random.normalvariate(12.5,4.1)) for _ in range(1000)]

# %%
values_normal,frequencies_normal=np.unique(normal_values,return_counts=True)

# %% [markdown]
# ### Barchart

# %%
axes=sns.barplot(x=values_normal, y=frequencies_normal,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
axes.set(xlim=(-1,25))
sns.set_style('whitegrid')
sns.set_context('poster')

# %% [markdown]
# ### Univariate distribution plot

# %%
axes=sns.distplot(normal_values,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
axes.set(xlim=(0,25))
# Out:
# [(0, 25)]

# %% [markdown]
# ### Line plot

# %%
axes=sns.lineplot(x=values_normal, y=frequencies_normal,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
axes.set(xlim=(0,25))
# Out:
# [(0, 25)]

# %% [markdown]
# ## Generating 100000 normally distributed values

# %%
normal_values1=[int(random.normalvariate(12.5,4.1)) for _ in range(100000)]

# %%
values_normal1,frequencies_normal1=np.unique(normal_values1,return_counts=True)

# %% [markdown]
# ### Bar chart

# %%
axes=sns.barplot(x=values_normal1, y=frequencies_normal1,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Values', ylabel='Frequencies')
# Out:
# [Text(0, 0.5, 'Frequencies'), Text(0.5, 0, 'Values')]

# %% [markdown]
# ### Univariate distribution plot

# %%
axes=sns.distplot(normal_values1,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Value')]

# %% [markdown]
# ### Line plot

# %%
axes=sns.lineplot(x=values_normal1, y=frequencies_normal1,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
axes.set(xlim=(0,25))
# Out:
# [(0, 25)]

# %% [markdown]
# ## Generating 1000 normally distributed random values over the range 0-100

# %%
normal_values2=[int(random.normalvariate(50,17)) for _ in range(1000)]

# %%
values_normal2,frequencies_normal2=np.unique(normal_values2,return_counts=True)

# %% [markdown]
# ### Line plot

# %%
axes=sns.lineplot(x=values_normal2, y=frequencies_normal2,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Value')]

# %% [markdown]
# ### Univariate distribution plot

# %%
axes=sns.distplot(normal_values2,color='#95a5a6')
axes.set_title('Normal Distribution')
axes.set(xlabel='Value', ylabel='Frequency')
# Out:
# [Text(0, 0.5, 'Frequency'), Text(0.5, 0, 'Value')]
